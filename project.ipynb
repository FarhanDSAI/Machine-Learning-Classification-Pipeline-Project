# %% [markdown]
# # Adult Income Classification Project

# %%
#See README and source files.
results = {'Logistic Regression': 0.8569966219674481, 'Decision Tree': 0.8191217115364929, 'KNN': 0.8385709898659024, 'SVC': 0.8555635172484389}
best_model = 'Logistic Regression'
